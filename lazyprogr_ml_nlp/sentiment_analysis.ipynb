# %%
# https://www.kaggle.com/crowdflower/twitter-airline-sentiment
# !wget -nc https://lazyprogrammer.me/course_files/AirlineTweets.csv
# Out:
# --2023-06-06 15:15:03--  https://lazyprogrammer.me/course_files/AirlineTweets.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 172.67.213.166, 104.21.23.210
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|172.67.213.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3421431 (3.3M) [text/csv]
# Saving to: 'AirlineTweets.csv'
#
#      0K .......... .......... .......... .......... ..........  1%  430K 8s
#     50K .......... .......... .......... .......... ..........  2%  412K 8s
#    100K .......... .......... .......... .......... ..........  4%  413K 8s
#    150K .......... .......... .......... .......... ..........  5%  398K 8s
#    200K .......... .......... .......... .......... ..........  7% 11.7M 6s
#    250K .......... .......... .......... .......... ..........  8%  441K 6s
#    300K .......... .......... .......... .......... .......... 10% 1.29M 5s
#    350K .......... .......... .......... .......... .......... 11%  556K 5s
#    400K .......... .......... .......... .......... .......... 13%  448K 5s
#    450K .......... .......... .......... .......... .......... 14% 7.45M 5s
#    500K .......... .......... .......... .......... .......... 16% 13.0M 4s
#    550K .......... .......... .......... .......... .......... 17% 1.62M 4s
#    600K .......... .......... .......... .......... .......... 19%  617K 4s
#    650K .......... .......... .......... .......... .......... 20% 7.86M 4s
#    700K .......... .......... .......... .......... .......... 22% 17.9M 3s
#    750K .......... .......... .......... .......... .......... 23% 1.64M 3s
#    800K .......... .......... .......... .......... .......... 25%  571K 3s
#    850K .......... .......... .......... .......... .......... 26% 19.8M 3s
#    900K .......... .......... .......... .......... .......... 28% 1.81M 3s
#    950K .......... .......... .......... .......... .......... 29% 14.7M 3s
#   1000K .......... .......... .......... .......... .......... 31% 25.5M 2s
#   1050K .......... .......... .......... .......... .......... 32%  591K 2s
#   1100K .......... .......... .......... .......... .......... 34% 26.7M 2s
#   1150K .......... .......... .......... .......... .......... 35% 14.1M 2s
#   1200K .......... .......... .......... .......... .......... 37% 1.79M 2s
#   1250K .......... .......... .......... .......... .......... 38%  594K 2s
#   1300K .......... .......... .......... .......... .......... 40% 23.7M 2s
#   1350K .......... .......... .......... .......... .......... 41% 16.7M 2s
#   1400K .......... .......... .......... .......... .......... 43% 18.4M 2s
#   1450K .......... .......... .......... .......... .......... 44% 28.8M 2s
#   1500K .......... .......... .......... .......... .......... 46% 1.89M 2s
#   1550K .......... .......... .......... .......... .......... 47%  586K 2s
#   1600K .......... .......... .......... .......... .......... 49% 41.0M 1s
#   1650K .......... .......... .......... .......... .......... 50% 24.8M 1s
#   1700K .......... .......... .......... .......... .......... 52% 24.6M 1s
#   1750K .......... .......... .......... .......... .......... 53% 25.5M 1s
#   1800K .......... .......... .......... .......... .......... 55% 11.4M 1s
#   1850K .......... .......... .......... .......... .......... 56% 18.9M 1s
#   1900K .......... .......... .......... .......... .......... 58% 2.13M 1s
#   1950K .......... .......... .......... .......... .......... 59% 1.11M 1s
#   2000K .......... .......... .......... .......... .......... 61% 1.09M 1s
#   2050K .......... .......... .......... .......... .......... 62% 14.1M 1s
#   2100K .......... .......... .......... .......... .......... 64%  140M 1s
#   2150K .......... .......... .......... .......... .......... 65% 21.4M 1s
#   2200K .......... .......... .......... .......... .......... 67% 30.9M 1s
#   2250K .......... .......... .......... .......... .......... 68% 24.2M 1s
#   2300K .......... .......... .......... .......... .......... 70% 33.8M 1s
#   2350K .......... .......... .......... .......... .......... 71% 2.61M 1s
#   2400K .......... .......... .......... .......... .......... 73% 27.1M 1s
#   2450K .......... .......... .......... .......... .......... 74%  608K 1s
#   2500K .......... .......... .......... .......... .......... 76% 12.8M 1s
#   2550K .......... .......... .......... .......... .......... 77% 25.6M 0s
#   2600K .......... .......... .......... .......... .......... 79% 28.3M 0s
#   2650K .......... .......... .......... .......... .......... 80% 29.9M 0s
#   2700K .......... .......... .......... .......... .......... 82% 23.5M 0s
#   2750K .......... .......... .......... .......... .......... 83% 21.0M 0s
#   2800K .......... .......... .......... .......... .......... 85% 36.4M 0s
#   2850K .......... .......... .......... .......... .......... 86% 28.2M 0s
#   2900K .......... .......... .......... .......... .......... 88% 2.31M 0s
#   2950K .......... .......... .......... .......... .......... 89% 30.4M 0s
#   3000K .......... .......... .......... .......... .......... 91%  613K 0s
#   3050K .......... .......... .......... .......... .......... 92% 32.6M 0s
#   3100K .......... .......... .......... .......... .......... 94% 21.3M 0s
#   3150K .......... .......... .......... .......... .......... 95% 23.4M 0s
#   3200K .......... .......... .......... .......... .......... 97% 26.1M 0s
#   3250K .......... .......... .......... .......... .......... 98% 25.9M 0s
#   3300K .......... .......... .......... .......... .         100% 55.2M=1.8s
#
# 2023-06-06 15:15:06 (1.80 MB/s) - 'AirlineTweets.csv' saved [3421431/3421431]

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

np.random.seed(1)

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
df_ = pd.read_csv("AirlineTweets.csv")
df_.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
df = df_[["airline_sentiment", "text"]].copy()
df.head()
# Out:
#   airline_sentiment                                               text
# 0           neutral                @VirginAmerica What @dhepburn said.
# 1          positive  @VirginAmerica plus you've added commercials t...
# 2           neutral  @VirginAmerica I didn't today... Must mean I n...
# 3          negative  @VirginAmerica it's really aggressive to blast...
# 4          negative  @VirginAmerica and it's a really big bad thing...

# %%
df["airline_sentiment"].hist()
# Out:
# <Axes: >

# %%
target_map = {"positive": 1, "negative": 0, "neutral": 2}
df["target"] = df["airline_sentiment"].map(target_map)

# %%
df.head()
# Out:
#   airline_sentiment                                               text  target
# 0           neutral                @VirginAmerica What @dhepburn said.       2
# 1          positive  @VirginAmerica plus you've added commercials t...       1
# 2           neutral  @VirginAmerica I didn't today... Must mean I n...       2
# 3          negative  @VirginAmerica it's really aggressive to blast...       0
# 4          negative  @VirginAmerica and it's a really big bad thing...       0

# %%
df_train, df_test = train_test_split(df)

# %%
df_train.head()
# Out:
#       airline_sentiment                                               text  \
# 4148           negative  @united here I was thinking how I could say so...
# 14166          negative  @AmericanAir fight got Cancelled Flighted can ...
# 5909           positive                @SouthwestAir Thank you. Great tool
# 2470           negative  .@united too much info to share via tweet. Ple...
# 4652           negative  @SouthwestAir but when do I get my gin &amp; t...
#
#        target
# 4148        0
# 14166       0
# 5909        1
# 2470        0
# 4652        0

# %%
vectorizer = TfidfVectorizer(max_features=2000)
X_train = vectorizer.fit_transform(df_train["text"])
X_train
# Out:
# <10980x2000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 157738 stored elements in Compressed Sparse Row format>

# %%
X_test = vectorizer.transform(df_test["text"])

# %%
Y_train = df_train["target"]
Y_test = df_test["target"]

# %%
model = LogisticRegression(max_iter=500)
model.fit(X_train, Y_train)
print("Train acc:", model.score(X_train, Y_train))
print("Test acc:", model.score(X_test, Y_test))
# Out:
# Train acc: 0.8561020036429873
# Test acc: 0.7997267759562842

# %%
Pr_train = model.predict_proba(X_train)#[:, 1]
Pr_test = model.predict_proba(X_test)#[:, 1]
print("Train AUC:", roc_auc_score(Y_train, Pr_train, multi_class="ovo"))
print("Test AUC:", roc_auc_score(Y_test, Pr_test, multi_class="ovo"))
# Out:
# Train AUC: 0.9427226297738796
# Test AUC: 0.8958925765525195

# %%
P_train = model.predict(X_train)
P_test = model.predict(X_test)

# %%
cm = confusion_matrix(Y_train, P_train, normalize="true")
cm
# Out:
# array([[0.96344648, 0.00899333, 0.0275602 ],
#        [0.19360366, 0.71216448, 0.09423187],
#        [0.30492505, 0.04796574, 0.64710921]])

# %%
def plot_cm(cm):
    classes = ["negative", "positive", "neutral"]
    df_cm = pd.DataFrame(cm, index=classes, columns=classes)
    ax = sn.heatmap(df_cm, annot=True, fmt="g")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Target")

plot_cm(cm)

# %%
cm_test = confusion_matrix(Y_test, P_test, normalize="true")
plot_cm(cm_test)

# %% [markdown]
# ## Binary Labels & Model Interpretation

# %%
binary_target_list = [target_map["positive"], target_map["negative"]]
df_b_train = df_train[df_train['target'].isin(binary_target_list)]
df_b_test = df_test[df_test["target"].isin(binary_target_list)]

# %%
df_b_train.head()
# Out:
#       airline_sentiment                                               text  \
# 4148           negative  @united here I was thinking how I could say so...
# 14166          negative  @AmericanAir fight got Cancelled Flighted can ...
# 5909           positive                @SouthwestAir Thank you. Great tool
# 2470           negative  .@united too much info to share via tweet. Ple...
# 4652           negative  @SouthwestAir but when do I get my gin &amp; t...
#
#        target
# 4148        0
# 14166       0
# 5909        1
# 2470        0
# 4652        0

# %%
X_train = vectorizer.fit_transform(df_b_train["text"])
X_test = vectorizer.transform(df_b_test["text"])

# %%
Y_train = df_b_train["target"]
Y_test = df_b_test["target"]

# %%
model = LogisticRegression(max_iter=500)
model.fit(X_train, Y_train)
print("Train acc: ", model.score(X_train, Y_train))
print("Tesst acc: ", model.score(X_test, Y_test))
# Out:
# Train acc:  0.929091960670908
# Tesst acc:  0.9105662983425414

# %%
Pr_train = model.predict_proba(X_train)[:, 1]
Pr_test = model.predict_proba(X_test)[:, 1]
print("Train AUC:", roc_auc_score(Y_train, Pr_train))
print("Test AUC:", roc_auc_score(Y_test, Pr_test))
# Out:
# Train AUC: 0.9789041348497116
# Test AUC: 0.9538126838592996

# %%
model.coef_
# Out:
# array([[-0.31804992,  0.33413639, -0.77929618, ..., -0.08243201,
#         -0.42615137,  0.21451666]])

# %%
plt.hist(model.coef_[0], bins=30)
# Out:
# (array([  1.,   1.,   3.,   3.,   3.,  12.,  39.,  71., 311., 829., 425.,
#         157.,  85.,  33.,  10.,   2.,   1.,   5.,   2.,   2.,   1.,   1.,
#           0.,   1.,   0.,   0.,   0.,   0.,   0.,   2.]),
#  array([-4.00724375e+00, -3.60583590e+00, -3.20442805e+00, -2.80302019e+00,
#         -2.40161234e+00, -2.00020448e+00, -1.59879663e+00, -1.19738878e+00,
#         -7.95980922e-01, -3.94573068e-01,  6.83478590e-03,  4.08242640e-01,
#          8.09650494e-01,  1.21105835e+00,  1.61246620e+00,  2.01387406e+00,
#          2.41528191e+00,  2.81668976e+00,  3.21809762e+00,  3.61950547e+00,
#          4.02091333e+00,  4.42232118e+00,  4.82372903e+00,  5.22513689e+00,
#          5.62654474e+00,  6.02795260e+00,  6.42936045e+00,  6.83076830e+00,
#          7.23217616e+00,  7.63358401e+00,  8.03499187e+00]),
#  <BarContainer object of 30 artists>)

# %%
word_index_map = vectorizer.vocabulary_
word_index_map
# Out:
# {'united': 1846,
#  'here': 874,
#  'was': 1902,
#  'thinking': 1745,
#  'how': 903,
#  'could': 448,
#  'say': 1528,
#  'so': 1614,
#  'many': 1108,
#  'nice': 1210,
#  'things': 1743,
#  'after': 111,
#  'getting': 803,
#  'upgraded': 1858,
#  'but': 297,
#  'then': 1738,
#  'you': 1993,
#  'delayed': 505,
#  'my': 1190,
#  'flight': 726,
#  'it': 968,
#  'ok': 1246,
#  'americanair': 147,
#  'fight': 699,
#  'got': 819,
#  'cancelled': 311,
#  'flighted': 730,
#  'can': 310,
#  'help': 869,
#  'me': 1116,
#  'rebook': 1433,
#  'call': 304,
#  'center': 335,
#  'is': 962,
#  'too': 1778,
#  'busy': 296,
#  'to': 1770,
#  'answer': 158,
#  'calls': 308,
#  'or': 1263,
#  'even': 629,
#  'put': 1408,
#  'on': 1250,
#  'hold': 884,
#  'southwestair': 1635,
#  'thank': 1730,
#  'great': 823,
#  'much': 1186,
#  'info': 944,
#  'share': 1568,
#  'via': 1881,
#  'tweet': 1820,
#  'please': 1350,
#  'send': 1551,
#  'your': 1995,
#  'name': 1193,
#  'and': 152,
#  'contact': 435,
#  'happy': 848,
#  'with': 1950,
#  'cs': 469,
#  'rep': 1457,
#  'names': 1194,
#  'when': 1933,
#  'do': 561,
#  'get': 801,
#  'amp': 150,
#  'usairways': 1865,
#  'of': 1238,
#  'seating': 1538,
#  'mom': 1166,
#  'together': 1773,
#  'toddler': 1772,
#  'in': 931,
#  'his': 881,
#  'own': 1284,
#  'row': 1503,
#  'fail': 669,
#  'cnn': 384,
#  'exactly': 638,
#  've': 1878,
#  'been': 246,
#  'disconnected': 552,
#  'times': 1765,
#  'well': 1925,
#  'have': 855,
#  'all': 130,
#  'day': 491,
#  'the': 1735,
#  'time': 1763,
#  'world': 1966,
#  'luggage': 1088,
#  'delivery': 510,
#  'between': 253,
#  'really': 1429,
#  'told': 1774,
#  'by': 300,
#  'midnight': 1144,
#  'multiple': 1187,
#  'why': 1940,
#  'lie': 1036,
#  'crazy': 462,
#  'bad': 226,
#  'business': 295,
#  'an': 151,
#  'inconvenience': 937,
#  'weather': 1915,
#  'delay': 504,
#  'pilot': 1334,
#  'waste': 1904,
#  'enough': 615,
#  'faa': 665,
#  'wouldn': 1976,
#  'let': 1029,
#  'him': 879,
#  'fly': 744,
#  'am': 143,
#  'looking': 1068,
#  'for': 754,
#  'award': 218,
#  'travel': 1793,
#  'booked': 271,
#  'wife': 1942,
#  'two': 1825,
#  'no': 1214,
#  'seats': 1539,
#  'assigned': 197,
#  'pls': 1352,
#  'this': 1747,
#  'resolved': 1477,
#  'reimbursement': 1451,
#  'made': 1092,
#  'msg': 1184,
#  'phone': 1328,
#  'number': 1232,
#  'email': 602,
#  'address': 105,
#  'jetblue': 978,
#  'thanks': 1731,
#  'us': 1862,
#  'nyc': 1236,
#  'jfk': 980,
#  'safely': 1516,
#  'long': 1064,
#  'does': 562,
#  'take': 1706,
#  'our': 1274,
#  'checked': 356,
#  'bags': 231,
#  'not': 1222,
#  'be': 241,
#  'more': 1174,
#  'wrong': 1979,
#  'http': 907,
#  'co': 385,
#  'trying': 1811,
#  'change': 343,
#  'due': 583,
#  'advisory': 109,
#  'online': 1255,
#  'system': 1702,
#  'entire': 618,
#  'over': 1280,
#  'hr': 905,
#  'where': 1934,
#  'airline': 123,
#  'people': 1316,
#  'screwed': 1535,
#  'up': 1853,
#  'boarding': 268,
#  'passes': 1302,
#  'way': 1911,
#  'back': 225,
#  'from': 775,
#  'horrible': 894,
#  'we': 1913,
#  'are': 180,
#  'making': 1099,
#  'worst': 1971,
#  'experience': 652,
#  'ever': 632,
#  'will': 1944,
#  'never': 1203,
#  'book': 270,
#  'again': 113,
#  'train': 1788,
#  'attendants': 206,
#  'better': 252,
#  'about': 78,
#  'hours': 900,
#  'because': 244,
#  'missed': 1160,
#  'connections': 430,
#  'mechanical': 1123,
#  'issues': 967,
#  '1st': 20,
#  'rebooked': 1434,
#  're': 1422,
#  'at': 201,
#  'gate': 796,
#  'im': 923,
#  'sure': 1691,
#  'll': 1054,
#  'eventually': 631,
#  'holding': 885,
#  'hostage': 895,
#  'as': 189,
#  'inbound': 932,
#  'gets': 802,
#  'push': 1407,
#  '15': 12,
#  'min': 1150,
#  'doing': 565,
#  'hrs': 906,
#  'cool': 441,
#  'canned': 313,
#  'response': 1482,
#  'nah': 1192,
#  'think': 1744,
#  'keep': 989,
#  'tweeting': 1821,
#  'everyone': 634,
#  'who': 1937,
#  'aa': 76,
#  'twitter': 1824,
#  'dm': 559,
#  'though': 1751,
#  'frustrated': 778,
#  'attitude': 208,
#  'members': 1129,
#  'they': 1741,
#  'sent': 1554,
#  'her': 873,
#  'letter': 1031,
#  'said': 1518,
#  'would': 1975,
#  'talk': 1711,
#  'stewardess': 1665,
#  'serving': 1561,
#  'drinks': 577,
#  'that': 1733,
#  'doesn': 563,
#  'care': 319,
#  'nor': 1220,
#  'sna': 1611,
#  'agent': 116,
#  'rude': 1507,
#  'had': 831,
#  'cabo': 303,
#  'thx': 1758,
#  'update': 1854,
#  'sold': 1616,
#  'seat': 1537,
#  'phx': 1330,
#  'three': 1753,
#  'obviously': 1237,
#  'corporate': 443,
#  'patience': 1305,
#  'needs': 1202,
#  'heard': 864,
#  'life': 1039,
#  'now': 1231,
#  'might': 1145,
#  'till': 1762,
#  'tomorrow': 1775,
#  'insane': 948,
#  'buy': 298,
#  'tix': 1767,
#  'days': 492,
#  'before': 247,
#  'transfer': 1790,
#  'security': 1542,
#  'customer': 477,
#  'service': 1559,
#  'seems': 1546,
#  'few': 697,
#  'friends': 773,
#  'speak': 1637,
#  'just': 987,
#  'need': 1200,
#  'find': 708,
#  'go': 811,
#  'sea': 1536,
#  'overnight': 1283,
#  'he': 858,
#  'already': 138,
#  'agents': 117,
#  'unhelpful': 1845,
#  'unacceptable': 1834,
#  'did': 534,
#  'through': 1754,
#  'one': 1253,
#  'knew': 998,
#  'anything': 166,
#  'bag': 229,
#  'ridiculous': 1490,
#  'still': 1667,
#  'don': 568,
#  'saturday': 1524,
#  'if': 920,
#  'only': 1256,
#  'tried': 1802,
#  'like': 1041,
#  'apology': 172,
#  'full': 784,
#  'refund': 1443,
#  'confirm': 421,
#  'receive': 1436,
#  'what': 1930,
#  'happens': 847,
#  'matters': 1112,
#  'drop': 580,
#  'ball': 232,
#  'la': 1004,
#  'airport': 126,
#  'gives': 807,
#  'absolute': 80,
#  'best': 251,
#  'checking': 358,
#  'easy': 595,
#  'miles': 1148,
#  'were': 1927,
#  'traveled': 1794,
#  'last': 1015,
#  'year': 1984,
#  'virginamerica': 1885,
#  'attendant': 205,
#  'wow': 1977,
#  'amazing': 144,
#  'same': 1520,
#  'happened': 845,
#  'couldn': 449,
#  'home': 886,
#  'next': 1208,
#  'flying': 748,
#  'out': 1276,
#  'bna': 265,
#  'today': 1771,
#  'crews': 465,
#  'ground': 824,
#  'handled': 837,
#  'situation': 1598,
#  'notification': 1229,
#  'catch': 328,
#  'during': 586,
#  'thru': 1756,
#  'details': 529,
#  'want': 1898,
#  'real': 1427,
#  'person': 1320,
#  'line': 1044,
#  'ticket': 1759,
#  'issued': 966,
#  'customers': 478,
#  '45': 53,
#  'minutes': 1157,
#  'speaking': 1638,
#  'lady': 1006,
#  'counter': 452,
#  'gave': 798,
#  'problem': 1388,
#  'laptop': 1012,
#  'process': 1390,
#  'experienced': 653,
#  'finally': 707,
#  'someone': 1622,
#  'worries': 1968,
#  'also': 139,
#  'group': 825,
#  'total': 1781,
#  'bs': 286,
#  'different': 540,
#  'departure': 520,
#  'arrival': 184,
#  'updates': 1856,
#  '1hr': 18,
#  'flights': 737,
#  'tell': 1721,
#  'stuck': 1675,
#  'original': 1267,
#  'several': 1563,
#  'waiting': 1893,
#  'cold': 390,
#  'love': 1078,
#  'southwest': 1634,
#  'rocks': 1496,
#  'always': 142,
#  'https': 908,
#  'kidding': 993,
#  'done': 569,
#  'called': 306,
#  'tells': 1723,
#  'hangs': 843,
#  'given': 806,
#  'memphis': 1130,
#  'taken': 1707,
#  'off': 1239,
#  'bc': 238,
#  'father': 684,
#  'lost': 1073,
#  'their': 1736,
#  'kept': 992,
#  'them': 1737,
#  '30': 36,
#  'trip': 1803,
#  'touch': 1783,
#  'surprise': 1692,
#  'otherwise': 1273,
#  'good': 818,
#  'feeling': 692,
#  'glad': 809,
#  'appreciate': 177,
#  'per': 1317,
#  'itinerary': 971,
#  'according': 91,
#  'dca': 494,
#  'yesterday': 1989,
#  'snow': 1613,
#  'flightling': 735,
#  'there': 1739,
#  'passengers': 1301,
#  'sitting': 1597,
#  'plane': 1341,
#  'cmh': 383,
#  'other': 1271,
#  'left': 1024,
#  'usairwaysfail': 1866,
#  'worstairlineever': 1972,
#  'sw': 1696,
#  'crew': 464,
#  'has': 851,
#  'notified': 1230,
#  'passenger': 1300,
#  'moved': 1180,
#  'water': 1910,
#  'fixed': 721,
#  'tarmac': 1715,
#  'top': 1780,
#  'free': 767,
#  'tv': 1819,
#  'int': 951,
#  'leg': 1025,
#  'houston': 902,
#  '70': 67,
#  'past': 1303,
#  'another': 157,
#  'plus': 1353,
#  'phlairport': 1326,
#  'manager': 1106,
#  'standing': 1654,
#  'lines': 1045,
#  'hour': 899,
#  'right': 1491,
#  'error': 622,
#  'load': 1055,
#  'message': 1136,
#  'price': 1381,
#  'matter': 1111,
#  'imaginedragons': 925,
#  'hear': 863,
#  'live': 1052,
#  'destinationdragons': 528,
#  'reservations': 1473,
#  'numbers': 1233,
#  'none': 1217,
#  'working': 1964,
#  'make': 1097,
#  'difficult': 541,
#  'any': 163,
#  'idea': 919,
#  'caused': 331,
#  'fll': 738,
#  'gt': 826,
#  'jax': 975,
#  'kind': 996,
#  'boston': 274,
#  'tonight': 1777,
#  'jet': 977,
#  'accept': 85,
#  'hit': 883,
#  'wait': 1891,
#  'should': 1577,
#  'drive': 578,
#  'desk': 525,
#  'yep': 1987,
#  'managed': 1104,
#  'hope': 891,
#  'ur': 1861,
#  'stuff': 1676,
#  'nothing': 1227,
#  'arrive': 185,
#  'late': 1016,
#  'leave': 1021,
#  '60': 64,
#  'connection': 429,
#  'disappointed': 547,
#  'terrible': 1726,
#  'flightled': 734,
#  'mean': 1119,
#  'rate': 1419,
#  'aren': 182,
#  'weeks': 1922,
#  'bank': 233,
#  'credit': 463,
#  'mechanics': 1124,
#  'teach': 1717,
#  'bring': 280,
#  'fix': 720,
#  'shout': 1579,
#  'pilots': 1335,
#  'super': 1686,
#  'landing': 1010,
#  'job': 982,
#  'having': 857,
#  'cant': 315,
#  'new': 1205,
#  'connecting': 428,
#  'staff': 1651,
#  'she': 1570,
#  'raleigh': 1417,
#  'updated': 1855,
#  'sounds': 1632,
#  'planned': 1343,
#  'since': 1592,
#  'completely': 411,
#  'flt': 742,
#  'hang': 841,
#  'minute': 1156,
#  'sending': 1552,
#  'gonna': 817,
#  'rock': 1495,
#  'redeem': 1441,
#  'points': 1357,
#  'gone': 816,
#  '10': 2,
#  'felt': 696,
#  'stop': 1668,
#  'cutting': 481,
#  'apologies': 170,
#  'some': 1619,
#  'additional': 104,
#  'reps': 1463,
#  'virgin': 1884,
#  'others': 1272,
#  'bos': 273,
#  'actual': 99,
#  'serv': 1557,
#  'model': 1165,
#  'booking': 272,
#  'problems': 1389,
#  'first': 715,
#  'frm': 774,
#  'mia': 1141,
#  'tpa': 1785,
#  'extremely': 662,
#  'irritated': 961,
#  'pit': 1337,
#  'iad': 914,
#  'board': 266,
#  'sit': 1595,
#  'half': 834,
#  'limit': 1043,
#  'deplane': 521,
#  'trouble': 1805,
#  'trueblue': 1807,
#  'despite': 526,
#  'able': 77,
#  'sign': 1588,
#  'happening': 846,
#  'phl': 1325,
#  'daughter': 490,
#  'hate': 853,
#  'says': 1530,
#  'try': 1810,
#  'check': 355,
#  '50': 58,
#  'voucher': 1888,
#  'ua': 1829,
#  'airways': 128,
#  'something': 1623,
#  'philly': 1324,
#  'awesome': 221,
#  'supposed': 1690,
#  'depart': 515,
#  '36': 43,
#  'departing': 517,
#  'finding': 709,
#  'lot': 1074,
#  'usairwayssucks': 1867,
#  'account': 92,
#  'hell': 867,
#  'answered': 159,
#  'options': 1262,
#  'monday': 1170,
#  'miss': 1159,
#  'work': 1961,
#  'paying': 1309,
#  'tickets': 1760,
#  'didn': 535,
#  'honestly': 888,
#  'quickly': 1415,
#  'possible': 1367,
#  'answers': 161,
#  'else': 601,
#  'coach': 386,
#  'looked': 1067,
#  'video': 1882,
#  'power': 1371,
#  'floor': 739,
#  'extra': 661,
#  'weren': 1928,
#  'relate': 1452,
#  'flightd': 729,
#  'understand': 1840,
#  'english': 613,
#  'pdx': 1313,
#  'hot': 896,
#  'form': 759,
#  'than': 1729,
#  'received': 1437,
#  'res': 1468,
#  'very': 1880,
#  'excited': 642,
#  'see': 1543,
#  'dfw': 531,
#  'cx': 483,
#  'lga': 1034,
#  'far': 679,
#  'shit': 1571,
#  'reflight': 1442,
#  'afford': 110,
#  'deal': 497,
#  'however': 904,
#  'type': 1828,
#  'self': 1549,
#  'policies': 1359,
#  'cost': 445,
#  'space': 1636,
#  'everything': 635,
#  'suitcase': 1683,
#  'believe': 250,
#  'guys': 829,
#  'vegas': 1879,
#  'employee': 607,
#  'running': 1512,
#  'helped': 870,
#  'emergency': 606,
#  'vacation': 1876,
#  'saved': 1526,
#  'issue': 965,
#  'confirmation': 422,
#  'shows': 1583,
#  'paid': 1287,
#  'week': 1920,
#  'sfo': 1565,
#  '5hrs': 63,
#  'engine': 612,
#  'sick': 1585,
#  'compensation': 406,
#  '20': 21,
#  'ipad': 959,
#  'filled': 705,
#  'found': 763,
#  'yall': 1982,
#  'mileage': 1146,
#  'reservation': 1472,
#  'yet': 1990,
#  'lax': 1017,
#  'promised': 1395,
#  'mess': 1135,
#  'spoke': 1646,
#  'mco': 1115,
#  'connect': 426,
#  'held': 866,
#  '26': 31,
#  'epicfail': 620,
#  'asked': 193,
#  'fee': 689,
#  '24': 28,
#  'explain': 656,
#  'dumb': 585,
#  'using': 1872,
#  'know': 999,
#  'aus': 209,
#  'swa': 1697,
#  'added': 102,
#  'consider': 431,
#  'letting': 1032,
#  'flyers': 746,
#  'overhead': 1282,
#  'bin': 257,
#  'items': 970,
#  'class': 370,
#  'sense': 1553,
#  'merger': 1134,
#  'going': 814,
#  'huge': 909,
#  'storm': 1670,
#  'flts': 743,
#  'figured': 701,
#  'case': 327,
#  'hopefully': 892,
#  'changing': 346,
#  'annoying': 156,
#  'clue': 382,
#  'beyond': 254,
#  'auto': 211,
#  'whatever': 1931,
#  '11': 5,
#  'reply': 1460,
#  'years': 1985,
#  'ago': 118,
#  'direct': 543,
#  'area': 181,
#  'learn': 1019,
#  'flew': 725,
#  'bought': 277,
#  'usair': 1864,
#  'dividend': 558,
#  'pay': 1308,
#  'st': 1650,
#  'san': 1521,
#  'juan': 986,
#  'spent': 1644,
#  'listening': 1048,
#  'yes': 1988,
#  'correct': 444,
#  'every': 633,
#  'chance': 341,
#  'keeping': 990,
#  'exec': 645,
#  'platinum': 1347,
#  'sorry': 1628,
#  'start': 1656,
#  'honeymoon': 889,
#  '8pm': 73,
#  'incident': 933,
#  'mint': 1155,
#  'company': 402,
#  'tweets': 1822,
#  'feels': 693,
#  'springs': 1649,
#  'look': 1066,
#  'return': 1485,
#  'car': 317,
#  'clt': 380,
#  'pick': 1331,
#  'denied': 513,
#  'hung': 912,
#  'second': 1541,
#  'coming': 396,
#  'provide': 1399,
#  'conf': 419,
#  'code': 388,
#  'ewr': 636,
#  'early': 590,
#  'jetway': 979,
#  'flightr': 736,
#  'somewhere': 1624,
#  'cause': 330,
#  'delivered': 509,
#  'especially': 624,
#  'member': 1128,
#  'part': 1295,
#  'calling': 307,
#  'cust': 476,
#  'twice': 1823,
#  'advise': 108,
#  'safe': 1515,
#  'forgot': 758,
#  'point': 1356,
#  'east': 594,
#  'checkin': 357,
#  'knowing': 1000,
#  'baggage': 230,
#  'count': 451,
#  'las': 1014,
#  'wonderful': 1956,
#  'claim': 368,
#  'earlier': 589,
#  'landed': 1009,
#  'along': 137,
#  'file': 702,
#  'located': 1057,
#  'bit': 260,
#  'actually': 100,
#  'ended': 611,
#  'driving': 579,
#  'lack': 1005,
#  'communication': 399,
#  '728': 69,
#  'returned': 1486,
#  'oh': 1245,
#  'anyone': 165,
#  'hates': 854,
#  'fact': 668,
#  'makes': 1098,
#  'poor': 1361,
#  'neveragain': 1204,
#  'lovely': 1081,
#  'helping': 872,
#  'instead': 950,
#  'into': 958,
#  'callback': 305,
#  'queue': 1413,
#  'longer': 1065,
#  'hotels': 898,
#  'available': 215,
#  'land': 1008,
#  'phoenix': 1327,
#  'unhappy': 1844,
#  'employees': 608,
#  '000': 1,
#  'dog': 564,
#  'sunday': 1685,
#  'shitty': 1572,
#  'showed': 1581,
#  'waited': 1892,
#  'come': 393,
#  'trips': 1804,
#  'met': 1139,
#  'seattle': 1540,
#  'down': 575,
#  'hotel': 897,
#  'broke': 282,
#  'cut': 480,
#  'short': 1574,
#  'peanuts': 1314,
#  'realize': 1428,
#  'leaves': 1022,
#  'folks': 749,
#  'handling': 839,
#  'less': 1028,
#  'arrived': 186,
#  '12': 6,
#  'being': 249,
#  'which': 1935,
#  'play': 1348,
#  'mins': 1154,
#  'telling': 1722,
#  'food': 753,
#  'spend': 1642,
#  'money': 1171,
#  'kudos': 1003,
#  'wish': 1949,
#  'rest': 1484,
#  'example': 639,
#  'follow': 750,
#  'non': 1216,
#  'except': 641,
#  'wasn': 1903,
#  'empty': 609,
#  'around': 183,
#  'open': 1258,
#  'boarded': 267,
#  'handle': 836,
#  'standby': 1653,
#  'reimbursed': 1450,
#  'american': 146,
#  'stand': 1652,
#  'fingers': 711,
#  'crossed': 467,
#  'layover': 1018,
#  'fuel': 783,
#  'kids': 994,
#  'anxious': 162,
#  'husband': 913,
#  'current': 474,
#  'changed': 344,
#  'ourselves': 1275,
#  'came': 309,
#  'each': 588,
#  'previous': 1380,
#  'guess': 827,
#  'airlines': 124,
#  'treated': 1799,
#  'loyal': 1084,
#  'columbus': 391,
#  'option': 1261,
#  '32': 41,
#  'feel': 691,
#  'night': 1211,
#  'traveling': 1797,
#  'rough': 1499,
#  'tho': 1749,
#  'fault': 685,
#  'big': 255,
#  'leaving': 1023,
#  'until': 1852,
#  'read': 1425,
#  'story': 1671,
#  'team': 1718,
#  'sleeping': 1606,
#  'dia': 533,
#  'loaded': 1056,
#  'list': 1047,
#  'preferred': 1375,
#  '14': 10,
#  'americanairlines': 148,
#  'watch': 1907,
#  'break': 279,
#  'fine': 710,
#  'print': 1383,
#  'lt': 1086,
#  'pretty': 1379,
#  'discuss': 554,
#  'experiences': 654,
#  'give': 805,
#  'shot': 1576,
#  'assistance': 200,
#  'following': 752,
#  'de': 495,
#  'runway': 1513,
#  'clear': 373,
#  'offer': 1240,
#  'vouchers': 1889,
#  'scheduled': 1532,
#  'takeoff': 1708,
#  'without': 1952,
#  'sky': 1603,
#  'eat': 596,
#  'sleep': 1605,
#  'single': 1593,
#  'most': 1177,
#  'human': 910,
#  'excuse': 643,
#  'treatment': 1801,
#  'either': 599,
#  'pvd': 1409,
#  'wifi': 1943,
#  'movie': 1181,
#  'dallas': 485,
#  'atlanta': 203,
#  'flightlations': 733,
#  'merged': 1133,
#  'frustrating': 779,
#  'responding': 1481,
#  'wtf': 1980,
#  'under': 1838,
#  'failed': 670,
#  'solution': 1617,
#  'lol': 1062,
#  'expect': 648,
#  'level': 1033,
#  'almost': 135,
#  'word': 1959,
#  'london': 1063,
#  'fare': 680,
#  'cities': 366,
#  'end': 610,
#  'pr': 1373,
#  '700': 68,
#  'losing': 1071,
#  'newark': 1206,
#  'four': 764,
#  'mind': 1151,
#  'pleasant': 1349,
#  'helpful': 871,
#  'excellent': 640,
#  'while': 1936,
#  'systems': 1703,
#  'place': 1338,
#  'svc': 1695,
#  'won': 1954,
#  'accommodate': 90,
#  '400': 50,
#  'charge': 348,
#  'mail': 1093,
#  'takes': 1709,
#  'priority': 1385,
#  'badservice': 228,
#  'tired': 1766,
#  '200': 22,
#  'worth': 1974,
#  '18': 16,
#  'trapped': 1792,
#  'denver': 514,
#  'worstcustomerservice': 1973,
#  'hasn': 852,
#  'miserable': 1158,
#  'orlando': 1269,
#  'nonstop': 1218,
#  'must': 1189,
#  'btw': 287,
#  'saying': 1529,
#  'talked': 1712,
#  '150': 13,
#  '25': 30,
#  'deserves': 524,
#  'raise': 1416,
#  'bringing': 281,
#  'thought': 1752,
#  'ord': 1264,
#  'exact': 637,
#  'carry': 324,
#  'apparently': 174,
#  'chicago': 361,
#  'assist': 199,
#  'taking': 1710,
#  'middle': 1143,
#  ...}

# %%
threshold = 2

print("Most positive words:")
for word, index in word_index_map.items():
    weight = model.coef_[0][index]
    if weight > threshold:
        print(word, weight)
# Out:
# Most positive words:
# southwestair 3.3399743434320124
# thank 7.7092085731975635
# great 5.521259239973937
# jetblue 3.118376204434974
# thanks 8.034991866645264
# cool 2.197739902304403
# thx 2.18072723785386
# best 3.617420665200286
# virginamerica 3.6426561808900173
# amazing 3.7387340297658116
# worries 2.963645055839749
# love 4.53928590746977
# good 3.122525849072174
# appreciate 2.9495104166640176
# awesome 4.175218606126934
# wonderful 2.5128192938926897
# kudos 2.860370249783668

# %%
print("Most negative words:")
for word, index in word_index_map.items():
    weight = model.coef_[0][index]
    if weight < -threshold:
        print(word, weight)
# Out:
# Most negative words:
# delayed -2.7456190877773436
# cancelled -2.4804172848307275
# hold -2.9348963297040873
# luggage -2.3158912458926686
# why -2.378104197313267
# no -3.58598503768629
# not -4.007243754471117
# worst -2.987705857739867
# hours -3.13338866659188
# what -2.4712791351856764
# nothing -2.140343465732431
